# %% [markdown]
# ## 作業一
#
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# #### 1. 你選的這組資料為何重要
# 答： 資料集：Google Job Skills https://www.kaggle.com/niyamatalmass/google-job-skills
#
# 對於想要進入Google工作的人，具有很大的參考價值。
# 經過分析Google的招聘網站內容，了解需要具備甚麼語言能力、技能和經驗，
# 才能進入Goolge中工作。
#
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 答： Google招聘網站 https://careers.google.com/
#
# #### 3. 蒐集而來的資料型態為何
# 答： 結構化表格
#
# #### 4. 這組資料想解決的問題如何評估
# 答： 根據職缺分析，找出與自身具備能力相接近的職缺去做準備。

# %% [markdown]
# ##  作業二
#
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# #### 1. 核心問題為何
# 乘客最怕的就是招車等待的時間過久，常就近隨機搭乘其他任意的車隊，漏失掉其載客的機會。
# 應根據乘客上車地點分布密度來配置空車的等待位置，降低乘客招攬車隊時的等待時間，
# 提升車隊與乘客間的觸及率。
#
# #### 2. 資料從何而來
# 乘客的搭乘紀錄。
#
# #### 3. 蒐集而來的資料型態為何
# 乘客搭乘時間、上車地點、下車地點所整理出來的結構化表格。
#
# #### 4. 你要回答的問題，其如何評估
# 計算各地區乘客的觸及率，將乘客觸及率低的區域做適時的調整空車的分配位置。

# %% [markdown]
# ## 作業三
#
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \displaystyle{ \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} } $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error( y, y_hat ):
    MSE = np.sum((y - y_hat)**2 ) / len(y)
    return MSE

# %%
def mean_absolute_error( y, y_hat ):
    MAE = np.sum(  np.abs( y - y_hat ) ) / len(y)
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 240.508
# The Mean absolute error is 12.740
